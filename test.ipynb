# %%
import os
import pandas as pd
from dataclasses import dataclass
from utils.logger import get_logger
import json

logger = get_logger()

with open("filtered_companies.json", "r", encoding="utf-8") as f:
    data = json.load(f)


new_dict = {}
for company in data:
    symbol = company["symbol"]
    new_dict[symbol] = company

with open("filtered_companies.json", "w", encoding="utf-8") as f:
    json.dump(new_dict, f, indent=4)
