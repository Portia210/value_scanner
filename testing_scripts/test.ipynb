# %%
import os
import pandas as pd
from dataclasses import dataclass
from utils.logger import get_logger
import json

logger = get_logger()

with open("filtered_companies.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
sectors = []
industries = []
for key, value in data.items():
    sector = value["sector"]
    industry = value["industry"]
    if sector not in sectors:
        sectors.append(sector)
    if industry not in industries:
        industries.append(industry)
        
print(sectors)
print(industries)
# Out:
# ['Technology', 'Consumer Discretionary', 'Financials', 'Healthcare', 'Communication Services', 'Consumer Staples', 'Industrials', 'Materials', 'Energy']
# ['Semiconductors', 'Auto Manufacturers', 'Insurance - Diversified', 'Medical Instruments & Supplies', 'Semiconductor Equipment & Materials', 'Asset Management', 'Computer Hardware', 'Biotechnology', 'Electronic Gaming & Multimedia', 'Software - Application', 'Financial Data & Stock Exchanges', 'Beverages - Non-Alcoholic', 'Information Technology Services', 'Medical Devices', 'Residential Construction', 'Industrial Distribution', 'Gold', 'Health Information Services', 'Specialty Business Services', 'Scientific & Technical Instruments', 'Steel', 'Insurance - Property & Casualty', 'Specialty Industrial Machinery', 'Apparel Retail', 'Drug Manufacturers - Specialty & Generic', 'Oil & Gas Exploration & Production', 'Aerospace & Defense', 'Tools & Accessories', 'Electronic Components', 'Software - Infrastructure', 'Footwear & Accessories', 'Insurance - Life', 'Agricultural Inputs', 'Metal Fabrication', 'Airports & Air Services', 'Building Products & Equipment', 'Discount Stores', 'Lumber & Wood Production', 'Pollution & Treatment Controls', 'Capital Markets', 'Packaged Foods', 'Insurance - Specialty', 'Lodging', 'Specialty Chemicals', 'Auto Parts', 'Oil & Gas Integrated', 'Education & Training Services', 'Electrical Equipment & Parts', 'Security & Protection Services', 'Engineering & Construction', 'Building Materials', 'Staffing & Employment Services', 'Oil & Gas Equipment & Services', 'Leisure', 'Apparel Manufacturing', 'Household & Personal Products', 'Rental & Leasing Services']
